# %% [markdown]
# Project: Minise Fintech company churn rate

# %% [markdown]
# The purpose of this project is to reduce or minimise the churn rate of a fintech company using ML models.

# %% [markdown]
# # 1. Import libraries

# %%
#import basic libs 
 import

# %% [markdown]
# # 2. Load & analyse data

# %% [markdown]
# # 3. Data visualisation
